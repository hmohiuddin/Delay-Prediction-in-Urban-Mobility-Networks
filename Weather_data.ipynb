# %% [markdown]
# # Collecting weather data

# %%
pip install wwo-hist

# %%
from wwo_hist import retrieve_hist_data

# %%
frequency=1
start_date = '01-JANUARY-2019'
end_date = '31-MARCH-2019'
api_key = '85bb095d867640a2a2f101801212011'
location_list = ['gottingen,germany']

hist_weather_data = retrieve_hist_data(api_key,
                                       location_list,
                                       start_date,
                                       end_date,frequency,
                                       location_label = False,
                                       export_csv = True, 
                                       store_df = True)

# %%
import pandas as pd

# %%
weather = pd.read_csv('/content/gottingen_germany.csv')

# %%
weather.head()
# Out:
#        date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  01-01-19 0:00         7         3           0.2      3.0        2
# 1  01-01-19 1:00         7         3           0.2      3.0        2
# 2  01-01-19 2:00         7         3           0.2      3.0        2
# 3  01-01-19 3:00         7         3           0.2      3.0        2
# 4  01-01-19 4:00         7         3           0.2      3.0        2
#
#    moon_illumination moonrise  moonset  sunrise  ... WindGustKmph  cloudcover  \
# 0                 26  3:28 AM  1:42 PM  8:26 AM  ...           22         100
# 1                 26  3:28 AM  1:42 PM  8:26 AM  ...           24         100
# 2                 26  3:28 AM  1:42 PM  8:26 AM  ...           25         100
# 3                 26  3:28 AM  1:42 PM  8:26 AM  ...           27         100
# 4                 26  3:28 AM  1:42 PM  8:26 AM  ...           29          99
#
#    humidity  precipMM  pressure  tempC  visibility  winddirDegree  \
# ...
